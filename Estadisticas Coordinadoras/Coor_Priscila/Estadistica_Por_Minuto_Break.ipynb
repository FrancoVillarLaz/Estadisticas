# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import time
import os
import numpy as np
# %matplotlib inline

ruta="C:/Users/LENOVO/OneDrive/Documentos/Estadisticas/Detalle Interacciones (Campaña - Lote).csv"
df=pd.read_csv(ruta,sep=';',encoding='utf-8')
df
# Out:
#      Empresa  Campaña                       Lote              Inicio  \
# 0        AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 11:41:02
# 1        AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 11:41:02
# 2        AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 11:41:02
# 3        AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 11:41:02
# 4        AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 11:41:02
# ...      ...      ...                        ...                 ...
# 4549     AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 15:52:59
# 4550     AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 15:52:59
# 4551     AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 15:53:04
# 4552     AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 15:53:19
# 4553     AZO  MVS_MZA  20250221_Mza_DNI_Personal  21/2/2025 15:53:24
#
#                   idInteraccion  Segmento Tipo Contacto       Cliente  \
# 0     250221114102679_ACD_46961         1       Llamada  111532141410
# 1     250221114102679_ACD_46963         1       Llamada  223155502189
# 2     250221114102679_ACD_46967         1       Llamada  221156125177
# 3     250221114102679_ACD_46971         1       Llamada  111556628372
# 4     250221114102679_ACD_46973         1       Llamada  295415613322
# ...                         ...       ...           ...           ...
# 4549  250221155259087_ACD_20877         1       Llamada  111561694673
# 4550  250221155259087_ACD_20889         1       Llamada  111539399055
# 4551  250221155304087_ACD_21087         1       Llamada  299154589769
# 4552  250221155319088_ACD_21457         1       Llamada  111565203194
# 4553  250221155324088_ACD_21659         1       Llamada  299156248475
#
#       idAgenteCliente  LoginID Agente Cliente  ...  TransferIn  TransferOut  \
# 0                 NaN                     NaN  ...           0            0
# 1                 NaN                     NaN  ...           0            0
# 2                 NaN                     NaN  ...           0            0
# 3                 NaN                     NaN  ...           0            0
# 4                 NaN                     NaN  ...           0            0
# ...               ...                     ...  ...         ...          ...
# 4549              NaN                     NaN  ...           0            0
# 4550              NaN                     NaN  ...           0            0
# 4551              NaN                     NaN  ...           0            0
# 4552              NaN                     NaN  ...           0            0
# 4553              NaN                     NaN  ...           0            0
#
#      Origen Corte Contexto                            Causa Terminación  \
# 0          Agente      NaN  Llamada no atendida por parte del abonado B
# 1          Agente      NaN                       Atiende un contestador
# 2          Agente      NaN  Llamada no atendida por parte del abonado B
# 3          Agente      NaN                El Cliente Atiende y No Habla
# 4          Agente      NaN  Llamada no atendida por parte del abonado B
# ...           ...      ...                                          ...
# 4549       Agente      NaN                       Atiende un contestador
# 4550      Cliente      NaN  Llamada no atendida por parte del abonado B
# 4551       Agente      NaN                       Atiende un contestador
# 4552      Cliente      NaN  Llamada no atendida por parte del abonado B
# 4553      Cliente      NaN  Llamada no atendida por parte del abonado B
#
#       idCausaQ850                           CausaQ850  idEmpresa  idCampania  \
# 0              19  No answer from user (user alerted)          1          23
# 1             131                         CONTESTADOR          1          23
# 2              19  No answer from user (user alerted)          1          23
# 3             132                            NO HABLA          1          23
# 4              19  No answer from user (user alerted)          1          23
# ...           ...                                 ...        ...         ...
# 4549          131                         CONTESTADOR          1          23
# 4550           18                  No user responding          1          23
# 4551          131                         CONTESTADOR          1          23
# 4552           18                  No user responding          1          23
# 4553           18                  No user responding          1          23
#
#       idLote
# 0       1550
# 1       1550
# 2       1550
# 3       1550
# 4       1550
# ...      ...
# 4549    1550
# 4550    1550
# 4551    1550
# 4552    1550
# 4553    1550
#
# [4554 rows x 49 columns]
